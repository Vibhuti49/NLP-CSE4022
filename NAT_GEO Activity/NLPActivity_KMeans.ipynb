# %%
import os
import pandas as pd
import numpy as np
data =pd.read_csv('NLP_NatGeoActivity.csv')
df = pd.DataFrame(data)
df
# Out:
#                                                 Title  \
# 0    A Culture Ride Through Chiang Mai and Chiang Rai
# 1                       Splendour at Sea in Koh Samui
# 2                    In Thailand, Nostalgia on Wheels
# 3                              A City’s State of Mind
# 4        The Great Outdoors May Not Be Great for Long
# 5                  Searching For Our Pop Culture Gods
# 6                       A Bombay Classic That Endures
# 7                                   Redefining #Goals
# 8                       Why Our Forests Need Watching
# 9                               A Soulmate for Summer
# 10                      How Deep Is Your Travel Love?
# 11  Travel Inspiration for 2019 : A Book on Nietzs...
# 12                               What Dreams May Come
# 13                                Free on the Outside
# 14                             In the Mood for Winter
# 15                            Slow Days, Fast Company
# 16                                   Train to Nowhere
# 17                            Six Years And Counting…
# 18                           Getting Saucy About Food
# 19                 There is More to France Than Paris
# 20                 Eye on the Tiger in Madhya Pradesh
# 21           Champagne: France’s Bottom’s Up Approach
# 22                              Life in a Paris Metro
# 23  Mountain Getaway | Setting up a Hammock in the...
# 24   Kalki Koechlin’s Art of Travel: Go with the Flow
# 25  Airbnb India’s Country Manager Amanpreet Bajaj...
# 26                               Taste Trumps Travel…
#
#                                           Description  \
# 0   From Buddhist shrines to spicy Lanna food--Tha...
# 1   Simple pleasures of island life mingle with re...
# 2   Riding across Thailand's idyllic villages, Bel...
# 3   To get under the skin of a great metropolis, u...
# 4   Shouldn't it matter to travellers that the clo...
# 5   Pop culture idols and their stories have the p...
# 6   Born of the city's streets, the vada pav is pr...
# 7   In the age of instant hype, once-in-a-lifetime...
# 8   In order to see animals in the wild, where we ...
# 9   The season never demands loyalty to a single d...
# 10  Passion for travel doesn't ring true until it ...
# 11  A philosophy professor's retracing of the Germ...
# 12  We are in the golden age of accessible travel....
# 13  A sense of elsewhere and that feeling of dislo...
# 14  Stark, freezing and quiet, the season's intens...
# 15  The difference between a road trip and any oth...
# 16  Travelling in India comes with a bit of pow-wo...
# 17  Grappling with an eternal conundrum about travel.
# 18  Scoring cultural brownie points over food is t...
# 19  Four cities in Northern France showcase decade...
# 20  The Kanha Earth Lodge and Pench Tree Lodge off...
# 21  Inside the atmospheric medieval cellars of Pan...
# 22  Commuting on the French capital’s busy train l...
# 23  A peaceful retreat with Ladakhi charms, Shey B...
# 24  Outdoorsy and bohemian, the Margarita with a S...
# 25  Before it became his occupation, travel was a ...
# 26  …Or does it? Taking stock of whether bad food ...
#
#                                               Content
# 0   Leaning out from a bridge leading into Wat Ron...
# 1   After a tiring snorkelling session in the clea...
# 2   As soon as a long, gleaming dark green train c...
# 3   The world’s greatest cities are brutal, unsent...
# 4   Part of the allure of a remote place is that t...
# 5   In this modern agnostic world, pop culture is ...
# 6   New and exciting has always received top billi...
# 7   Once-in-a-lifetime is an overused expression i...
# 8   J R.R. Tolkien was right to portray the Ents, ...
# 9   Every summer, the pastoral call of their mothe...
# 10  If there is a phrase I would prefer to retire ...
# 11  One of the finer books I read this year was Jo...
# 12  Our year-end edition toasts ultra-indulgence w...
# 13  The great outdoors, around which our November ...
# 14  Summer is a charming flirt. Easy-going and cas...
# 15  In the mid-2000s, I had the first of my severa...
# 16  I like a bit of pow-wow in any place. Let me r...
# 17  Anniversary editions have the feel of a gradua...
# 18  For my money, memorable disagreements often ce...
# 19                               In 2008, the comedy
# 20  It had been a dismal evening for Harpreet “Hap...
# 21  I check my smartphone for the time—11.40 a.m.—...
# 22  A few days before my brief stay in Paris this ...
# 23  Shey Bhumi is the kind of place that sends the...
# 24  There are moments when the therapeutic benefit...
# 25  Amanpreet Bajaj is by all accounts a busy man,...
# 26  All of us take cues from our families on how t...

# %%
df['Content']
# Out:
# 0     Leaning out from a bridge leading into Wat Ron...
# 1     After a tiring snorkelling session in the clea...
# 2     As soon as a long, gleaming dark green train c...
# 3     The world’s greatest cities are brutal, unsent...
# 4     Part of the allure of a remote place is that t...
# 5     In this modern agnostic world, pop culture is ...
# 6     New and exciting has always received top billi...
# 7     Once-in-a-lifetime is an overused expression i...
# 8     J R.R. Tolkien was right to portray the Ents, ...
# 9     Every summer, the pastoral call of their mothe...
# 10    If there is a phrase I would prefer to retire ...
# 11    One of the finer books I read this year was Jo...
# 12    Our year-end edition toasts ultra-indulgence w...
# 13    The great outdoors, around which our November ...
# 14    Summer is a charming flirt. Easy-going and cas...
# 15    In the mid-2000s, I had the first of my severa...
# 16    I like a bit of pow-wow in any place. Let me r...
# 17    Anniversary editions have the feel of a gradua...
# 18    For my money, memorable disagreements often ce...
# 19                                 In 2008, the comedy
# 20    It had been a dismal evening for Harpreet “Hap...
# 21    I check my smartphone for the time—11.40 a.m.—...
# 22    A few days before my brief stay in Paris this ...
# 23    Shey Bhumi is the kind of place that sends the...
# 24    There are moments when the therapeutic benefit...
# 25    Amanpreet Bajaj is by all accounts a busy man,...
# 26    All of us take cues from our families on how t...
# Name: Content, dtype: object

# %%
corpus = df['Content'].tolist()

# %%
#corpus

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(corpus)

true_k = 3
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i,:10]:
        print(' %s' % terms[ind])
# Out:
# Top terms per cluster:
# Cluster 0:
#  summer
#  comedy
#  2008
#  year
#  place
#  john
#  day
#  books
#  read
#  kaag
# Cluster 1:
#  food
#  open
#  restaurant
#  minded
#  appetite
#  families
#  instances
#  took
#  cues
#  kanha
# Cluster 2:
#  travel
#  world
#  culture
#  just
#  love
#  sense
#  bucket
#  doesn
#  business
#  job

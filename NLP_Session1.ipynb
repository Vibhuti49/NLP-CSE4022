# %%
import nltk

# %%
#TASK 1
from nltk.corpus import brown
#brown.categories()
brown.words(categories = "mystery")[:50]
# Out:
# ['There',
#  'were',
#  'thirty-eight',
#  'patients',
#  'on',
#  'the',
#  'bus',
#  'the',
#  'morning',
#  'I',
#  'left',
#  'for',
#  'Hanover',
#  ',',
#  'most',
#  'of',
#  'them',
#  'disturbed',
#  'and',
#  'hallucinating',
#  '.',
#  'An',
#  'interne',
#  ',',
#  'a',
#  'nurse',
#  'and',
#  'two',
#  'attendants',
#  'were',
#  'in',
#  'charge',
#  'of',
#  'us',
#  '.',
#  'I',
#  'felt',
#  'lonely',
#  'and',
#  'depressed',
#  'as',
#  'I',
#  'stared',
#  'out',
#  'the',
#  'bus',
#  'window',
#  'at',
#  "Chicago's",
#  'grim']

# %%
#TASK 2
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
#TASK3
inaugural.words(fileids = '2013-Obama.txt')[:10]
# Out:
# ['Thank', 'you', '.', 'Thank', 'you', 'so', 'much', '.', 'Vice', 'President']

# %%
inaugural.words(fileids = '1865-Lincoln.txt')[:50]
# Out:
# ['Fellow',
#  '-',
#  'Countrymen',
#  ':',
#  'At',
#  'this',
#  'second',
#  'appearing',
#  'to',
#  'take',
#  'the',
#  'oath',
#  'of',
#  'the',
#  'Presidential',
#  'office',
#  'there',
#  'is',
#  'less',
#  'occasion',
#  'for',
#  'an',
#  'extended',
#  'address',
#  'than',
#  'there',
#  'was',
#  'at',
#  'the',
#  'first',
#  '.',
#  'Then',
#  'a',
#  'statement',
#  'somewhat',
#  'in',
#  'detail',
#  'of',
#  'a',
#  'course',
#  'to',
#  'be',
#  'pursued',
#  'seemed',
#  'fitting',
#  'and',
#  'proper',
#  '.',
#  'Now',
#  ',']

# %%
inaugural.words(fileids = '2017-Trump.txt')[:50]
# Out:
# ['Chief',
#  'Justice',
#  'Roberts',
#  ',',
#  'President',
#  'Carter',
#  ',',
#  'President',
#  'Clinton',
#  ',',
#  'President',
#  'Bush',
#  ',',
#  'President',
#  'Obama',
#  ',',
#  'fellow',
#  'Americans',
#  ',',
#  'and',
#  'people',
#  'of',
#  'the',
#  'world',
#  ':',
#  'Thank',
#  'you',
#  '.',
#  'We',
#  ',',
#  'the',
#  'citizens',
#  'of',
#  'America',
#  ',',
#  'are',
#  'now',
#  'joined',
#  'in',
#  'a',
#  'great',
#  'national',
#  'effort',
#  'to',
#  'rebuild',
#  'our',
#  'country',
#  'and',
#  'restore',
#  'its']

# %%
#TASK 4 
from nltk.corpus import webtext
#nltk.download('webtext')
webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
#TASK 5 - Frequency distribution

text1 = "Who doesn't love receiving a little blue box all of their jewelry is clean and classy sleek and just about does anything. One of my favorite necklaces from Tiffany's is one that my best friends got me for graduation when it broke the customer service was awesome with getting it fixed. They have beautiful pieces and although they are lovely , I find them over priced on sterling silver, that is my opinion, we have many of the pieces for my daughter that were given to her as gifts. My husband and I went in to a Tiffany's to shop for an engagement ring and were hardly given the time of day by the sales people.” al jeweler for a much lower price!"
fd = nltk.FreqDist(text1.split())
fd
# Out:
# FreqDist({'and': 5, 'of': 4, 'my': 4, 'for': 4, 'the': 4, 'a': 3, 'is': 3, 'that': 3, 'to': 3, "Tiffany's": 2, ...})

# %%
#TASK 6 - Conditional Frequency distribution
from nltk.probability import ConditionalFreqDist
cfd = ConditionalFreqDist((len(word),word)for word in text1.split())
cfd[5]
# Out:
# FreqDist({'given': 2, 'their': 1, 'clean': 1, 'sleek': 1, 'about': 1, 'broke': 1, 'sales': 1, 'lower': 1})

# %%
#HOME WORK- To determine Frequency Distribution and 
#Conditional Frequency Distribution of any one of the 
#Presidential inaugural addresses 
#Word Cloud using Wordnet
inauguraltext = inaugural.words(fileids = '2013-Obama.txt')
fd1 = nltk.FreqDist(inauguraltext)
cfd1 = ConditionalFreqDist((len(word),word)for word in inauguraltext)
#print("Frequency Distribution:")
#print(fd1)
#print(" Conditional Frequency Distribution for words with 6 letters:")
#print(cfd1[6])

# %%
fd1
# Out:
# FreqDist({'the': 100, ',': 99, '.': 91, 'and': 85, 'of': 69, 'our': 69, 'to': 66, 'that': 51, 'we': 46, 'a': 36, ...})

# %%
cfd[6]
# Out:
# FreqDist({'pieces': 2, 'little': 1, 'classy': 1, 'fixed.': 1, 'lovely': 1, 'priced': 1, 'gifts.': 1, 'hardly': 1, 'price!': 1})

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd 
stopwords = set(STOPWORDS)
comment_words = ''
comment_words += " ".join(inauguraltext)+" "
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
